# %%
import zipfile

# %%
pip install gdown
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\tom\anaconda3\envs\nlp\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\tom\anaconda3\envs\nlp\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\tom\anaconda3\envs\nlp\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\tom\anaconda3\envs\nlp\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\tom\anaconda3\envs\nlp\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\tom\anaconda3\envs\nlp\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\tom\anaconda3\envs\nlp\lib\site-packages)

# %%
# !gdown 1IAxZxf65Qh7noQMjhBpJ7iz42nRsW23r
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1IAxZxf65Qh7noQMjhBpJ7iz42nRsW23r
# To: c:\Users\Tom\Desktop\Centrale\G3\OSP\PDI\OCT_GANs\oct_drusen_sample.png
#
#   0%|          | 0.00/3.11M [00:00<?, ?B/s]
#  17%|█▋        | 524k/3.11M [00:00<00:03, 696kB/s]
#  34%|███▎      | 1.05M/3.11M [00:01<00:02, 729kB/s]
#  51%|█████     | 1.57M/3.11M [00:02<00:02, 624kB/s]
#  67%|██████▋   | 2.10M/3.11M [00:04<00:02, 412kB/s]
#  84%|████████▍ | 2.62M/3.11M [00:06<00:01, 324kB/s]
# 100%|██████████| 3.11M/3.11M [00:07<00:00, 342kB/s]
# 100%|██████████| 3.11M/3.11M [00:07<00:00, 396kB/s]

# %%
# !gdown https://drive.google.com/drive/folders/1YDdMbbDGoJFxzOvy2FflQT7QXe0eWqcX?usp=sharing -O ./generated_images --folder --remaining-ok
# Out:
# Retrieving folder 1AG56YAaVNvHfw3z9IF2EhT0WuWKlb0pX v11
# Processing file 1-hEjWBnhuCiwfs6md5z4y0kD481UEjCr img_0.png
# Processing file 12UPsAHj6Ib3upBaQGlqIzAbqkXLfaCdz img_1.png
# Processing file 10rnFSN0WYmKf9jDTR1LdpJ1GEv2SXYas img_2.png
# Processing file 10JrW26sWLsfnFkTd64bTW-1Tuo1axD8l img_3.png
# Processing file 12UtqA5sUiYKytSGcBwOguzerDv3Q9Eh0 img_4.png
# Processing file 13699mTvCajPqchqQJbZ6fXlAvyoMBrUT img_5.png
# Processing file 11XnMTnjSqDsdI-FGDwt1GyB8EYNpbXab img_6.png
# Processing file 11AYHxYHHUBcT0UuyBHjBZayPY8Xf0rwE img_7.png
# Processing file 1-0Q8rzRFAiK_-hJPlzH_zzU9HeD38DtU img_8.png
# Processing file 10Wf0PJTiQ-7vUWdbX3fsaRfucK2OI-R4 img_9.png
# Processing file 10_deZ8bNKquyDoPdJRnoXCcl6mMpb_Lw img_10.png
# Processing file 10uMwFVy89TBE8yimlwI6W99juwyixGYi img_11.png
# Processing file 12yVltHGEe02dQ4fHCZmQT7lSXXi7vqVK img_12.png
# Processing file 12lTlSjwibizUm9QzoWS-wQ_9FyPpAgPJ img_13.png
# Processing file 10OPXM6uESUahlxPjxvQ7O0JANeRPIKxS img_14.png
# ...
